# %%
import random
import time

maze = [
    ["#", "#", "#", "#", "#", "#", "#", "#"],
    ["#", "P", ".", ".", "#", ".", "E", "#"],
    ["#", "#", "#", ".", "#", ".", "#", "#"],
    ["#", ".", "G", ".", ".", ".", ".", "#"],
    ["#", "#", "#", "#", "#", "#", "#", "#"]
]

# Function to display the maze
def print_maze():
    for row in maze:
        print(" ".join(row))
    print("\n")

# Function to find the position of an element (P, G, E)
def find_position(symbol):
    for i in range(len(maze)):
        for j in range(len(maze[i])):
            if maze[i][j] == symbol:
                return (i, j)
    return None

def move_player(direction):
    global maze
    px, py = find_position("P")


# Calculate new position based on input
    new_x, new_y = px, py
    if direction == "W": new_x -= 1  # Up
    elif direction == "S": new_x += 1  # Down
    elif direction == "A": new_y -= 1  # Left
    elif direction == "D": new_y += 1 # Right
    import random
import time

# Define the maze grid
maze = [
    ["#", "#", "#", "#", "#", "#", "#", "#"],
    ["#", "P", ".", ".", "#", ".", "E", "#"],
    ["#", "#", "#", ".", "#", ".", "#", "#"],
    ["#", ".", "G", ".", ".", ".", ".", "#"],
    ["#", "#", "#", "#", "#", "#", "#", "#"]
]

# Function to display the maze
def print_maze():
    for row in maze:
        print(" ".join(row))
    print("\n")

# Function to find the position of an element (P, G, E)
def find_position(symbol):
    for i in range(len(maze)):
        for j in range(len(maze[i])):
            if maze[i][j] == symbol:
                return (i, j)
    return None

# Function to move the player
def move_player(direction):
    global maze
    px, py = find_position("P")
    
    # Calculate new position based on input
    new_x, new_y = px, py
    if direction == "W": new_x -= 1  # Up
    elif direction == "S": new_x += 1  # Down
    elif direction == "A": new_y -= 1  # Left
    elif direction == "D": new_y += 1  # Right
    if maze[new_x][new_y] in [".", "E"]:
        maze[new_x][new_y] = "P" 
        if [new_x][ new_y] == find_position("E"): 
            print("Congratulations! You escaped the haunted maze!")
        else if[new_x][new_y]=="#":
            print("Cant go to the wall")


def move_ghosts():
    global maze
    px, py = find_position("P")
    gx, gy = find_position("G")
    
        
def game_loop():
    print("Welcome to the Haunted Maze! Escape before the ghosts catch you!")
    print_maze()

    while True:
        direction = input("Move (W/A/S/D): ").upper()
        if direction not in ["W", "A", "S", "D"]:
            print("Invalid move! Use W (up), A (left), S (down), D (right)")
            continue

        move_player(direction)  # Move player
        move_ghosts()  # Move ghosts
        print_maze()
        if px==gx and py==gy:
            print("You caught by Ghost")
            break
        elif px==ex and py ==ey:
            print("You Escaped")
        else:
            continue
        



game_loop()
# Out:
#   Cell In[3], line 78
#     else if[new_x][new_y]=="#":
#          ^
# SyntaxError: expected ':'
